# %%
import numpy as np
import pandas as pd

train_df = pd.read_csv("/home/nitesh/Desktop/house-price-prediction/train.csv")
test_df = pd.read_csv("/home/nitesh/Desktop/house-price-prediction/test.csv")

# %%
print(train_df.shape)
# Out:
# (1460, 81)

# %%
print(test_df.shape)
# Out:
# (1459, 80)
